# %%
import requests

url="http://127.0.0.1:8000/predict"

payload={"size_sqft":100,"bedrooms":2}

# %%
response=requests.post(url,json=payload)

# %%
response.json()["predicted_price"]
# Out:
# 122.0805393234256

# %%
url="http://127.0.0.1:8000/predict_batch"

# %%
payload={
    "houses":[
        {"size_sqft":200,"bedrooms":3},
        {"size_sqft":1500,"bedrooms":2},
        {"size_sqft":3200,"bedrooms":5}
    ]
}

# %%
response= requests.post(url,json=payload)

# %%
response.json()
# Out:
# {'predicted_prices': [205.66262609044793,
#   543.2070211073066,
#   1215.0797631922544]}
